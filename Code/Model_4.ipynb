# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tqdm import tqdm
import itertools
from tensorflow.keras.models import load_model
import random
from tensorflow.keras.preprocessing import image
from matplotlib import interactive
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import TensorBoard
import pickle
import time
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K
import matplotlib.image as mpimg


img_width, img_height = 150, 150

train_data_dir = "C:/Users/20115/Desktop/Covid_Phenomena_Dataset/train"
validation_data_dir = "C:/Users/20115/Desktop/Covid_Phenomena_Dataset/validation"
nb_train_samples = 753
nb_validation_samples = 201
epochs = 15
batch_size = 16

if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)


model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(3 , activation='softmax'))


loss='categorical_crossentropy'



model.compile(loss=loss,
              optimizer='rmsprop',
              metrics=['accuracy'])

train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(150, 150),
    batch_size=16,class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(150, 150),
    batch_size=16,class_mode='categorical')

history = model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)

model.save_weights('7try.h5')



print(model.summary())
model.save('Covid_Phenomena_7.model')
# Out:
# Found 753 images belonging to 3 classes.
# Found 201 images belonging to 3 classes.
# Epoch 1/15
# 47/47 [==============================] - 32s 674ms/step - loss: 1.0719 - accuracy: 0.5536 - val_loss: 0.5907 - val_accuracy: 0.8021
# Epoch 2/15
# 47/47 [==============================] - 32s 672ms/step - loss: 0.6536 - accuracy: 0.7246 - val_loss: 0.3511 - val_accuracy: 0.8698
# Epoch 3/15
# 47/47 [==============================] - 30s 634ms/step - loss: 0.6989 - accuracy: 0.7436 - val_loss: 0.3833 - val_accuracy: 0.8698
# Epoch 4/15
# 47/47 [==============================] - 30s 629ms/step - loss: 0.4979 - accuracy: 0.8112 - val_loss: 0.3361 - val_accuracy: 0.8646
# Epoch 5/15
# 47/47 [==============================] - 31s 650ms/step - loss: 0.4565 - accuracy: 0.8352 - val_loss: 0.2565 - val_accuracy: 0.9010
# Epoch 6/15
# 47/47 [==============================] - 48s 1s/step - loss: 0.4136 - accuracy: 0.8277 - val_loss: 0.2276 - val_accuracy: 0.9167
# Epoch 7/15
# 47/47 [==============================] - 33s 694ms/step - loss: 0.3702 - accuracy: 0.8657 - val_loss: 0.2042 - val_accuracy: 0.9219
# Epoch 8/15
# 47/47 [==============================] - 34s 714ms/step - loss: 0.3892 - accuracy: 0.8587 - val_loss: 0.2430 - val_accuracy: 0.9219
# Epoch 9/15
# 47/47 [==============================] - 35s 755ms/step - loss: 0.3165 - accuracy: 0.8833 - val_loss: 0.2095 - val_accuracy: 0.9427
# Epoch 10/15
# 47/47 [==============================] - 31s 659ms/step - loss: 0.2697 - accuracy: 0.9056 - val_loss: 0.1973 - val_accuracy: 0.9323
# Epoch 11/15
# 47/47 [==============================] - 33s 702ms/step - loss: 0.2492 - accuracy: 0.9077 - val_loss: 0.2477 - val_accuracy: 0.9010
# Epoch 12/15
# 47/47 [==============================] - 38s 816ms/step - loss: 0.2113 - accuracy: 0.9172 - val_loss: 0.1287 - val_accuracy: 0.9531
# Epoch 13/15
# 47/47 [==============================] - 40s 861ms/step - loss: 0.1991 - accuracy: 0.9280 - val_loss: 0.2383 - val_accuracy: 0.9375
# Epoch 14/15
# 47/47 [==============================] - 29s 624ms/step - loss: 0.2031 - accuracy: 0.9403 - val_loss: 0.1275 - val_accuracy: 0.9635
# Epoch 15/15
# 47/47 [==============================] - 34s 730ms/step - loss: 0.1756 - accuracy: 0.9308 - val_loss: 0.0904 - val_accuracy: 0.9792
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# activation_8 (Activation)    (None, 148, 148, 32)      0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 72, 72, 32)        9248
# _________________________________________________________________
# activation_9 (Activation)    (None, 72, 72, 32)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 34, 34, 64)        18496
# _________________________________________________________________
# activation_10 (Activation)   (None, 34, 34, 64)        0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18496)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                1183808
# _________________________________________________________________
# activation_11 (Activation)   (None, 64)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 1,212,643
# Trainable params: 1,212,643
# Non-trainable params: 0
# _________________________________________________________________
# None
# INFO:tensorflow:Assets written to: Covid_Phenomena_7.model\assets

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Accuracy', 'Val_Accuracy'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Loss', 'Val_Loss'], loc='upper left')
plt.show()
