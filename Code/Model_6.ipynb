# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tqdm import tqdm
import itertools
from tensorflow.keras.models import load_model
import random
from tensorflow.keras.preprocessing import image
from matplotlib import interactive
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import TensorBoard
import pickle
import time
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K
import matplotlib.image as mpimg




img_width, img_height = 150, 150

train_data_dir = "C:/Users/20115/Desktop/Exp/train"
validation_data_dir = "C:/Users/20115/Desktop/Exp/validation"
nb_train_samples = 477
nb_validation_samples = 477
epochs = 20
batch_size = 16

if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)


model = Sequential()
model.add(Conv2D(32, (5, 5), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(3 , activation='softmax'))


loss='categorical_crossentropy'



model.compile(loss=loss,
              optimizer='rmsprop',
              metrics=['accuracy'])

train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(150, 150),
    batch_size=16,class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(150, 150),
    batch_size=16,class_mode='categorical')

history = model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)



print(model.summary())
model.save('Covid_Phenomena_9.model')
# Out:
# Found 477 images belonging to 3 classes.
# Found 477 images belonging to 3 classes.
# Epoch 1/20
# 29/29 [==============================] - 39s 1s/step - loss: 1.4905 - accuracy: 0.4273 - val_loss: 0.8647 - val_accuracy: 0.6142
# Epoch 2/20
# 29/29 [==============================] - 36s 1s/step - loss: 0.8862 - accuracy: 0.5970 - val_loss: 0.6457 - val_accuracy: 0.7220
# Epoch 3/20
# 29/29 [==============================] - 36s 1s/step - loss: 0.7719 - accuracy: 0.7009 - val_loss: 0.5987 - val_accuracy: 0.7716
# Epoch 4/20
# 29/29 [==============================] - 36s 1s/step - loss: 0.6201 - accuracy: 0.7570 - val_loss: 0.3413 - val_accuracy: 0.8642
# Epoch 5/20
# 29/29 [==============================] - 36s 1s/step - loss: 0.5853 - accuracy: 0.7592 - val_loss: 0.3538 - val_accuracy: 0.8772
# Epoch 6/20
# 29/29 [==============================] - 35s 1s/step - loss: 0.6739 - accuracy: 0.7592 - val_loss: 0.4111 - val_accuracy: 0.8362
# Epoch 7/20
# 29/29 [==============================] - 36s 1s/step - loss: 0.5073 - accuracy: 0.7939 - val_loss: 0.3654 - val_accuracy: 0.8513
# Epoch 8/20
# 29/29 [==============================] - 37s 1s/step - loss: 0.5834 - accuracy: 0.8351 - val_loss: 0.3496 - val_accuracy: 0.8578
# Epoch 9/20
# 29/29 [==============================] - 39s 1s/step - loss: 0.4326 - accuracy: 0.8470 - val_loss: 0.4108 - val_accuracy: 0.8319
# Epoch 10/20
# 29/29 [==============================] - 40s 1s/step - loss: 0.4927 - accuracy: 0.8221 - val_loss: 0.2942 - val_accuracy: 0.8750
# Epoch 11/20
# 29/29 [==============================] - 43s 1s/step - loss: 0.6283 - accuracy: 0.8122 - val_loss: 0.2721 - val_accuracy: 0.8944
# Epoch 12/20
# 29/29 [==============================] - 36s 1s/step - loss: 0.4213 - accuracy: 0.8578 - val_loss: 0.3322 - val_accuracy: 0.8621
# Epoch 13/20
# 29/29 [==============================] - 33s 1s/step - loss: 0.4365 - accuracy: 0.8319 - val_loss: 0.2420 - val_accuracy: 0.9095
# Epoch 14/20
# 29/29 [==============================] - 25s 853ms/step - loss: 0.3413 - accuracy: 0.8655 - val_loss: 0.2021 - val_accuracy: 0.9289
# Epoch 15/20
# 29/29 [==============================] - 25s 862ms/step - loss: 0.3901 - accuracy: 0.8556 - val_loss: 0.2245 - val_accuracy: 0.9073
# Epoch 16/20
# 29/29 [==============================] - 24s 823ms/step - loss: 0.3033 - accuracy: 0.8742 - val_loss: 0.2747 - val_accuracy: 0.8772
# Epoch 17/20
# 29/29 [==============================] - 24s 845ms/step - loss: 0.4053 - accuracy: 0.8493 - val_loss: 0.1660 - val_accuracy: 0.9440
# Epoch 18/20
# 29/29 [==============================] - 24s 819ms/step - loss: 0.3036 - accuracy: 0.8980 - val_loss: 0.2375 - val_accuracy: 0.9246
# Epoch 19/20
# 29/29 [==============================] - 23s 797ms/step - loss: 0.3046 - accuracy: 0.8915 - val_loss: 0.2626 - val_accuracy: 0.8879
# Epoch 20/20
# 29/29 [==============================] - 23s 802ms/step - loss: 0.2699 - accuracy: 0.8966 - val_loss: 0.1152 - val_accuracy: 0.9547
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 146, 146, 32)      2432
# _________________________________________________________________
# activation_28 (Activation)   (None, 146, 146, 32)      0
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 73, 73, 32)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 71, 71, 32)        9248
# _________________________________________________________________
# activation_29 (Activation)   (None, 71, 71, 32)        0
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 35, 35, 32)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 33, 33, 64)        18496
# _________________________________________________________________
# activation_30 (Activation)   (None, 33, 33, 64)        0
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                1048640
# _________________________________________________________________
# activation_31 (Activation)   (None, 64)                0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 3)                 195
# =================================================================
# Total params: 1,079,011
# Trainable params: 1,079,011
# Non-trainable params: 0
# _________________________________________________________________
# None
# INFO:tensorflow:Assets written to: Covid_Phenomena_9.model\assets

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Accuracy', 'Val_Accuracy'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Loss', 'Val_Loss'], loc='upper left')
plt.show()
