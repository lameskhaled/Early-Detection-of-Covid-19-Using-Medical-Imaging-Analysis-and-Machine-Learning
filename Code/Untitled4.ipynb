# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
import pickle
import time

pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

X = X/255.0

dense_layers = [0, 1, 2]
layer_sizes = [32, 64, 128]
conv_layers = [1, 2, 3]

for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME = "{}-conv-{}-nodes-{}-dense-{}".format(conv_layer, layer_size, dense_layer, int(time.time()))
            print(NAME)

            model = Sequential()

            model.add(Conv2D(layer_size, (3, 3), input_shape=X.shape[1:]))
            model.add(Activation('relu'))
            model.add(MaxPooling2D(pool_size=(2, 2)))

            for l in range(conv_layer-1):
                model.add(Conv2D(layer_size, (3, 3)))
                model.add(Activation('relu'))
                model.add(MaxPooling2D(pool_size=(2, 2)))

            model.add(Flatten())

            for _ in range(dense_layer):
                model.add(Dense(layer_size))
                model.add(Activation('relu'))

            model.add(Dense(1))
            model.add(Activation('sigmoid'))
            
            X = np.array(X).reshape(-1, 50, 50, 1)

            y = np.array(y)

            tensorboard = TensorBoard(log_dir="logs\{}".format(NAME))

            model.compile(loss='binary_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy'],
                          )

            model.fit(X, y,
                      batch_size=32,
                      epochs=4,
                      validation_split=0.3,
                      callbacks=[tensorboard])



model.save('64x3-CNN.model')
# Out:
# 1-conv-32-nodes-0-dense-1588475902
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.5167 - accuracy: 0.7685 - val_loss: 0.3192 - val_accuracy: 0.9476
# Epoch 2/4
# 445/445 [==============================] - 0s 527us/sample - loss: 0.2457 - accuracy: 0.9303 - val_loss: 0.1770 - val_accuracy: 0.9686
# Epoch 3/4
# 445/445 [==============================] - 0s 487us/sample - loss: 0.1647 - accuracy: 0.9416 - val_loss: 0.1441 - val_accuracy: 0.9529
# Epoch 4/4
# 445/445 [==============================] - 0s 489us/sample - loss: 0.1340 - accuracy: 0.9551 - val_loss: 0.1137 - val_accuracy: 0.9634
# 2-conv-32-nodes-0-dense-1588475904
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 1s 3ms/sample - loss: 0.6720 - accuracy: 0.6337 - val_loss: 0.6212 - val_accuracy: 0.9005
# Epoch 2/4
# 445/445 [==============================] - 1s 1ms/sample - loss: 0.5366 - accuracy: 0.9213 - val_loss: 0.4089 - val_accuracy: 0.9529
# Epoch 3/4
# 445/445 [==============================] - 0s 1ms/sample - loss: 0.3137 - accuracy: 0.9393 - val_loss: 0.2209 - val_accuracy: 0.9476
# Epoch 4/4
# 445/445 [==============================] - 0s 844us/sample - loss: 0.1854 - accuracy: 0.9416 - val_loss: 0.1505 - val_accuracy: 0.9476
# 3-conv-32-nodes-0-dense-1588475907
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 1s 3ms/sample - loss: 0.6756 - accuracy: 0.6539 - val_loss: 0.6549 - val_accuracy: 0.5812
# Epoch 2/4
# 445/445 [==============================] - 0s 907us/sample - loss: 0.6068 - accuracy: 0.8831 - val_loss: 0.5249 - val_accuracy: 0.9267
# Epoch 3/4
# 445/445 [==============================] - 0s 1ms/sample - loss: 0.4335 - accuracy: 0.9258 - val_loss: 0.3151 - val_accuracy: 0.9267
# Epoch 4/4
# 445/445 [==============================] - 1s 1ms/sample - loss: 0.2822 - accuracy: 0.9169 - val_loss: 0.2867 - val_accuracy: 0.9110
# 1-conv-64-nodes-0-dense-1588475910
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.5427 - accuracy: 0.7236 - val_loss: 0.3226 - val_accuracy: 0.9581
# Epoch 2/4
# 445/445 [==============================] - 0s 968us/sample - loss: 0.2509 - accuracy: 0.9258 - val_loss: 0.1865 - val_accuracy: 0.9476
# Epoch 3/4
# 445/445 [==============================] - 1s 1ms/sample - loss: 0.1648 - accuracy: 0.9348 - val_loss: 0.1344 - val_accuracy: 0.9476
# Epoch 4/4
# 445/445 [==============================] - 1s 1ms/sample - loss: 0.1009 - accuracy: 0.9708 - val_loss: 0.1254 - val_accuracy: 0.9372
# 2-conv-64-nodes-0-dense-1588475913
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 1s 3ms/sample - loss: 0.6215 - accuracy: 0.6764 - val_loss: 0.4968 - val_accuracy: 0.8429
# Epoch 2/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.3375 - accuracy: 0.9236 - val_loss: 0.1958 - val_accuracy: 0.9424
# Epoch 3/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.1751 - accuracy: 0.9438 - val_loss: 0.1373 - val_accuracy: 0.9634
# Epoch 4/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.1056 - accuracy: 0.9618 - val_loss: 0.1219 - val_accuracy: 0.9476
# 3-conv-64-nodes-0-dense-1588475917
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 1s 3ms/sample - loss: 0.6725 - accuracy: 0.5798 - val_loss: 0.6312 - val_accuracy: 0.5340
# Epoch 2/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.5949 - accuracy: 0.6764 - val_loss: 0.4668 - val_accuracy: 0.8953
# Epoch 3/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.3321 - accuracy: 0.9483 - val_loss: 0.1986 - val_accuracy: 0.9424
# Epoch 4/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.1360 - accuracy: 0.9573 - val_loss: 0.1281 - val_accuracy: 0.9581
# 1-conv-128-nodes-0-dense-1588475921
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 1s 3ms/sample - loss: 0.5202 - accuracy: 0.7730 - val_loss: 0.2691 - val_accuracy: 0.9634
# Epoch 2/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.2051 - accuracy: 0.9281 - val_loss: 0.1764 - val_accuracy: 0.9372
# Epoch 3/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.1646 - accuracy: 0.9416 - val_loss: 0.2087 - val_accuracy: 0.9267
# Epoch 4/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.0976 - accuracy: 0.9663 - val_loss: 0.1023 - val_accuracy: 0.9476
# 2-conv-128-nodes-0-dense-1588475926
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 2s 5ms/sample - loss: 0.5761 - accuracy: 0.7236 - val_loss: 0.3693 - val_accuracy: 0.8796
# Epoch 2/4
# 445/445 [==============================] - 2s 4ms/sample - loss: 0.2441 - accuracy: 0.9169 - val_loss: 0.1840 - val_accuracy: 0.9215
# Epoch 3/4
# 445/445 [==============================] - 2s 4ms/sample - loss: 0.1481 - accuracy: 0.9438 - val_loss: 0.1146 - val_accuracy: 0.9529
# Epoch 4/4
# 445/445 [==============================] - 2s 4ms/sample - loss: 0.0797 - accuracy: 0.9708 - val_loss: 0.0727 - val_accuracy: 0.9738
# 3-conv-128-nodes-0-dense-1588475934
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 3s 6ms/sample - loss: 0.6636 - accuracy: 0.5978 - val_loss: 0.5558 - val_accuracy: 0.9005
# Epoch 2/4
# 445/445 [==============================] - 2s 5ms/sample - loss: 0.3792 - accuracy: 0.9393 - val_loss: 0.1816 - val_accuracy: 0.9424
# Epoch 3/4
# 445/445 [==============================] - 2s 5ms/sample - loss: 0.1136 - accuracy: 0.9596 - val_loss: 0.0836 - val_accuracy: 0.9634
# Epoch 4/4
# 445/445 [==============================] - 2s 5ms/sample - loss: 0.0483 - accuracy: 0.9843 - val_loss: 0.0639 - val_accuracy: 0.9686
# 1-conv-32-nodes-1-dense-1588475943
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.3112 - accuracy: 0.8809 - val_loss: 0.1299 - val_accuracy: 0.9686
# Epoch 2/4
# 445/445 [==============================] - 0s 545us/sample - loss: 0.1031 - accuracy: 0.9551 - val_loss: 0.0664 - val_accuracy: 0.9791
# Epoch 3/4
# 445/445 [==============================] - 0s 536us/sample - loss: 0.0436 - accuracy: 0.9910 - val_loss: 0.0489 - val_accuracy: 0.9791
# Epoch 4/4
# 445/445 [==============================] - 0s 686us/sample - loss: 0.0313 - accuracy: 0.9955 - val_loss: 0.1141 - val_accuracy: 0.9529
# 2-conv-32-nodes-1-dense-1588475945
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 1s 3ms/sample - loss: 0.6149 - accuracy: 0.7303 - val_loss: 0.4862 - val_accuracy: 0.7696
# Epoch 2/4
# 445/445 [==============================] - 0s 941us/sample - loss: 0.3546 - accuracy: 0.8966 - val_loss: 0.2174 - val_accuracy: 0.9319
# Epoch 3/4
# 445/445 [==============================] - 1s 1ms/sample - loss: 0.1737 - accuracy: 0.9348 - val_loss: 0.1504 - val_accuracy: 0.9476
# Epoch 4/4
# 445/445 [==============================] - 1s 1ms/sample - loss: 0.1278 - accuracy: 0.9551 - val_loss: 0.1148 - val_accuracy: 0.9476
# 3-conv-32-nodes-1-dense-1588475948
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.6796 - accuracy: 0.6652 - val_loss: 0.6434 - val_accuracy: 0.5340
# Epoch 2/4
# 445/445 [==============================] - 1s 1ms/sample - loss: 0.6007 - accuracy: 0.7910 - val_loss: 0.4921 - val_accuracy: 0.8586
# Epoch 3/4
# 445/445 [==============================] - 1s 1ms/sample - loss: 0.3840 - accuracy: 0.9101 - val_loss: 0.2465 - val_accuracy: 0.9529
# Epoch 4/4
# 445/445 [==============================] - 1s 1ms/sample - loss: 0.2031 - accuracy: 0.9303 - val_loss: 0.1554 - val_accuracy: 0.9529
# 1-conv-64-nodes-1-dense-1588475951
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.5500 - accuracy: 0.7371 - val_loss: 0.2745 - val_accuracy: 0.9476
# Epoch 2/4
# 445/445 [==============================] - 1s 1ms/sample - loss: 0.1860 - accuracy: 0.9416 - val_loss: 0.1110 - val_accuracy: 0.9686
# Epoch 3/4
# 445/445 [==============================] - 1s 1ms/sample - loss: 0.0790 - accuracy: 0.9775 - val_loss: 0.0601 - val_accuracy: 0.9843
# Epoch 4/4
# 445/445 [==============================] - 1s 1ms/sample - loss: 0.0414 - accuracy: 0.9888 - val_loss: 0.0450 - val_accuracy: 0.9895
# 2-conv-64-nodes-1-dense-1588475955
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 1s 3ms/sample - loss: 0.6823 - accuracy: 0.6472 - val_loss: 0.5865 - val_accuracy: 0.9162
# Epoch 2/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.4238 - accuracy: 0.8809 - val_loss: 0.2110 - val_accuracy: 0.9634
# Epoch 3/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.1713 - accuracy: 0.9528 - val_loss: 0.1350 - val_accuracy: 0.9424
# Epoch 4/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.1114 - accuracy: 0.9618 - val_loss: 0.0890 - val_accuracy: 0.9476
# 3-conv-64-nodes-1-dense-1588475959
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 1s 3ms/sample - loss: 0.6786 - accuracy: 0.5730 - val_loss: 0.6271 - val_accuracy: 0.5550
# Epoch 2/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.4993 - accuracy: 0.8584 - val_loss: 0.3002 - val_accuracy: 0.9215
# Epoch 3/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.2273 - accuracy: 0.9258 - val_loss: 0.1472 - val_accuracy: 0.9581
# Epoch 4/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.1215 - accuracy: 0.9551 - val_loss: 0.1154 - val_accuracy: 0.9581
# 1-conv-128-nodes-1-dense-1588475964
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 2s 4ms/sample - loss: 0.9667 - accuracy: 0.5348 - val_loss: 0.4469 - val_accuracy: 0.9319
# Epoch 2/4
# 445/445 [==============================] - 1s 3ms/sample - loss: 0.3433 - accuracy: 0.9236 - val_loss: 0.1897 - val_accuracy: 0.9634
# Epoch 3/4
# 445/445 [==============================] - 1s 3ms/sample - loss: 0.1322 - accuracy: 0.9663 - val_loss: 0.0855 - val_accuracy: 0.9634
# Epoch 4/4
# 445/445 [==============================] - 1s 3ms/sample - loss: 0.0606 - accuracy: 0.9798 - val_loss: 0.0511 - val_accuracy: 0.9895
# 2-conv-128-nodes-1-dense-1588475970
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 2s 5ms/sample - loss: 0.5726 - accuracy: 0.7011 - val_loss: 0.2582 - val_accuracy: 0.9476
# Epoch 2/4
# 445/445 [==============================] - 2s 4ms/sample - loss: 0.1650 - accuracy: 0.9416 - val_loss: 0.0854 - val_accuracy: 0.9634
# Epoch 3/4
# 445/445 [==============================] - 2s 4ms/sample - loss: 0.0649 - accuracy: 0.9775 - val_loss: 0.0961 - val_accuracy: 0.9686
# Epoch 4/4
# 445/445 [==============================] - 2s 4ms/sample - loss: 0.0637 - accuracy: 0.9730 - val_loss: 0.0549 - val_accuracy: 0.9738
# 3-conv-128-nodes-1-dense-1588475978
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 3s 6ms/sample - loss: 0.6712 - accuracy: 0.6202 - val_loss: 0.5833 - val_accuracy: 0.9476
# Epoch 2/4
# 445/445 [==============================] - 2s 5ms/sample - loss: 0.4491 - accuracy: 0.8067 - val_loss: 0.3453 - val_accuracy: 0.8586
# Epoch 3/4
# 445/445 [==============================] - 2s 5ms/sample - loss: 0.2216 - accuracy: 0.9281 - val_loss: 0.1301 - val_accuracy: 0.9634
# Epoch 4/4
# 445/445 [==============================] - 2s 5ms/sample - loss: 0.0853 - accuracy: 0.9663 - val_loss: 0.0682 - val_accuracy: 0.9686
# 1-conv-32-nodes-2-dense-1588475988
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 1s 1ms/sample - loss: 0.4940 - accuracy: 0.7416 - val_loss: 0.2887 - val_accuracy: 0.8901
# Epoch 2/4
# 445/445 [==============================] - 0s 669us/sample - loss: 0.1837 - accuracy: 0.9371 - val_loss: 0.1283 - val_accuracy: 0.9686
# Epoch 3/4
# 445/445 [==============================] - 0s 788us/sample - loss: 0.1130 - accuracy: 0.9551 - val_loss: 0.0956 - val_accuracy: 0.9791
# Epoch 4/4
# 445/445 [==============================] - 0s 822us/sample - loss: 0.0790 - accuracy: 0.9708 - val_loss: 0.0766 - val_accuracy: 0.9634
# 2-conv-32-nodes-2-dense-1588475990
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.6596 - accuracy: 0.6539 - val_loss: 0.5634 - val_accuracy: 0.9581
# Epoch 2/4
# 445/445 [==============================] - 0s 1ms/sample - loss: 0.4015 - accuracy: 0.9348 - val_loss: 0.2279 - val_accuracy: 0.9476
# Epoch 3/4
# 445/445 [==============================] - 1s 1ms/sample - loss: 0.1652 - accuracy: 0.9393 - val_loss: 0.1341 - val_accuracy: 0.9634
# Epoch 4/4
# 445/445 [==============================] - 1s 1ms/sample - loss: 0.1107 - accuracy: 0.9596 - val_loss: 0.1131 - val_accuracy: 0.9634
# 3-conv-32-nodes-2-dense-1588475992
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.6886 - accuracy: 0.5685 - val_loss: 0.6704 - val_accuracy: 0.8115
# Epoch 2/4
# 445/445 [==============================] - 1s 1ms/sample - loss: 0.6548 - accuracy: 0.6697 - val_loss: 0.5976 - val_accuracy: 0.5864
# Epoch 3/4
# 445/445 [==============================] - 1s 1ms/sample - loss: 0.5138 - accuracy: 0.8831 - val_loss: 0.3556 - val_accuracy: 0.9529
# Epoch 4/4
# 445/445 [==============================] - 1s 1ms/sample - loss: 0.3059 - accuracy: 0.9169 - val_loss: 0.1660 - val_accuracy: 0.9476
# 1-conv-64-nodes-2-dense-1588475996
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 1s 3ms/sample - loss: 0.4672 - accuracy: 0.7573 - val_loss: 0.1935 - val_accuracy: 0.9634
# Epoch 2/4
# 445/445 [==============================] - 1s 1ms/sample - loss: 0.1459 - accuracy: 0.9438 - val_loss: 0.2602 - val_accuracy: 0.8953
# Epoch 3/4
# 445/445 [==============================] - 1s 1ms/sample - loss: 0.1987 - accuracy: 0.9056 - val_loss: 0.1182 - val_accuracy: 0.9634
# Epoch 4/4
# 445/445 [==============================] - 1s 1ms/sample - loss: 0.1121 - accuracy: 0.9528 - val_loss: 0.0632 - val_accuracy: 0.9791
# 2-conv-64-nodes-2-dense-1588475999
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 1s 3ms/sample - loss: 0.6058 - accuracy: 0.6382 - val_loss: 0.5061 - val_accuracy: 0.7225
# Epoch 2/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.2712 - accuracy: 0.9146 - val_loss: 0.1612 - val_accuracy: 0.9581
# Epoch 3/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.1256 - accuracy: 0.9551 - val_loss: 0.0812 - val_accuracy: 0.9791
# Epoch 4/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.0493 - accuracy: 0.9798 - val_loss: 0.0479 - val_accuracy: 0.9843
# 3-conv-64-nodes-2-dense-1588476004
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 1s 3ms/sample - loss: 0.6932 - accuracy: 0.4831 - val_loss: 0.6758 - val_accuracy: 0.5340
# Epoch 2/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.6421 - accuracy: 0.7618 - val_loss: 0.5243 - val_accuracy: 0.8901
# Epoch 3/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.3798 - accuracy: 0.8989 - val_loss: 0.2026 - val_accuracy: 0.9529
# Epoch 4/4
# 445/445 [==============================] - 1s 2ms/sample - loss: 0.1535 - accuracy: 0.9438 - val_loss: 0.1817 - val_accuracy: 0.9319
# 1-conv-128-nodes-2-dense-1588476009
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 2s 4ms/sample - loss: 0.5756 - accuracy: 0.6719 - val_loss: 0.2056 - val_accuracy: 0.9634
# Epoch 2/4
# 445/445 [==============================] - 1s 3ms/sample - loss: 0.1551 - accuracy: 0.9371 - val_loss: 0.0978 - val_accuracy: 0.9529
# Epoch 3/4
# 445/445 [==============================] - 1s 3ms/sample - loss: 0.0757 - accuracy: 0.9730 - val_loss: 0.0397 - val_accuracy: 0.9948
# Epoch 4/4
# 445/445 [==============================] - 1s 3ms/sample - loss: 0.0257 - accuracy: 0.9933 - val_loss: 0.0505 - val_accuracy: 0.9843
# 2-conv-128-nodes-2-dense-1588476015
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 2s 5ms/sample - loss: 0.5015 - accuracy: 0.8315 - val_loss: 0.1804 - val_accuracy: 0.9529
# Epoch 2/4
# 445/445 [==============================] - 2s 4ms/sample - loss: 0.1376 - accuracy: 0.9483 - val_loss: 0.1097 - val_accuracy: 0.9581
# Epoch 3/4
# 445/445 [==============================] - 2s 4ms/sample - loss: 0.0618 - accuracy: 0.9820 - val_loss: 0.0710 - val_accuracy: 0.9791
# Epoch 4/4
# 445/445 [==============================] - 2s 4ms/sample - loss: 0.0223 - accuracy: 0.9955 - val_loss: 0.2566 - val_accuracy: 0.9058
# 3-conv-128-nodes-2-dense-1588476024
# Train on 445 samples, validate on 191 samples
# Epoch 1/4
# 445/445 [==============================] - 3s 6ms/sample - loss: 0.6304 - accuracy: 0.6494 - val_loss: 0.4237 - val_accuracy: 0.9215
# Epoch 2/4
# 445/445 [==============================] - 2s 4ms/sample - loss: 0.3677 - accuracy: 0.8764 - val_loss: 0.3325 - val_accuracy: 0.8953
# Epoch 3/4
# 445/445 [==============================] - 2s 5ms/sample - loss: 0.2336 - accuracy: 0.9258 - val_loss: 0.1581 - val_accuracy: 0.9634
# Epoch 4/4
# 445/445 [==============================] - 2s 5ms/sample - loss: 0.1197 - accuracy: 0.9618 - val_loss: 0.0860 - val_accuracy: 0.9843
# WARNING:tensorflow:From C:\Users\20115\Anaconda3\envs\Covid\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: 64x3-CNN.model\assets
