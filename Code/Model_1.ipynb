# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tqdm import tqdm
import itertools
from tensorflow.keras.models import load_model
import random
from tensorflow.keras.preprocessing import image
from matplotlib import interactive
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import TensorBoard
import pickle
import time
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K
import matplotlib.image as mpimg


img_width, img_height = 150, 150

train_data_dir = "C:/Users/20115/Desktop/Covid_Phenomena_Dataset/train"
validation_data_dir = "C:/Users/20115/Desktop/Covid_Phenomena_Dataset/validation"
nb_train_samples = 753
nb_validation_samples = 201
epochs = 20
batch_size = 16

if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)
    
    

model = Sequential()
model.add(Conv2D(24, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(48, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(96, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))
    

loss='categorical_crossentropy'



model.compile(loss=loss,
              optimizer='rmsprop',
              metrics=['accuracy'])

train_datagen = ImageDataGenerator(rescale=1. / 255)

# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(150, 150),
    batch_size=16,class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(150, 150),
    batch_size=16,class_mode='categorical')

history = model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)




print(model.summary())
model.save('Covid_Phenomena_FirstTrail.model')
# Out:
# Found 753 images belonging to 3 classes.
# Found 201 images belonging to 3 classes.
# Epoch 1/20
# 47/47 [==============================] - 16s 349ms/step - loss: 1.0447 - accuracy: 0.4478 - val_loss: 0.7770 - val_accuracy: 0.6094
# Epoch 2/20
# 47/47 [==============================] - 17s 354ms/step - loss: 0.5865 - accuracy: 0.7720 - val_loss: 0.3096 - val_accuracy: 0.8854
# Epoch 3/20
# 47/47 [==============================] - 22s 471ms/step - loss: 0.5012 - accuracy: 0.8372 - val_loss: 0.2199 - val_accuracy: 0.9115
# Epoch 4/20
# 47/47 [==============================] - 34s 721ms/step - loss: 0.2528 - accuracy: 0.9118 - val_loss: 0.2096 - val_accuracy: 0.9323
# Epoch 5/20
# 47/47 [==============================] - 25s 535ms/step - loss: 0.3745 - accuracy: 0.8860 - val_loss: 0.2184 - val_accuracy: 0.9167
# Epoch 6/20
# 47/47 [==============================] - 24s 519ms/step - loss: 0.1132 - accuracy: 0.9661 - val_loss: 0.2846 - val_accuracy: 0.9219
# Epoch 7/20
# 47/47 [==============================] - 25s 539ms/step - loss: 0.1216 - accuracy: 0.9601 - val_loss: 1.0232 - val_accuracy: 0.8229
# Epoch 8/20
# 47/47 [==============================] - 25s 541ms/step - loss: 0.1356 - accuracy: 0.9557 - val_loss: 0.3038 - val_accuracy: 0.9115
# Epoch 9/20
# 47/47 [==============================] - 27s 572ms/step - loss: 0.0751 - accuracy: 0.9747 - val_loss: 0.1629 - val_accuracy: 0.9688
# Epoch 10/20
# 47/47 [==============================] - 26s 546ms/step - loss: 0.1025 - accuracy: 0.9751 - val_loss: 0.2534 - val_accuracy: 0.9271
# Epoch 11/20
# 47/47 [==============================] - 26s 563ms/step - loss: 0.1243 - accuracy: 0.9647 - val_loss: 0.1262 - val_accuracy: 0.9635
# Epoch 12/20
# 47/47 [==============================] - 27s 572ms/step - loss: 0.0250 - accuracy: 0.9919 - val_loss: 0.2427 - val_accuracy: 0.9323
# Epoch 13/20
# 47/47 [==============================] - 27s 569ms/step - loss: 0.0785 - accuracy: 0.9783 - val_loss: 0.1560 - val_accuracy: 0.9583
# Epoch 14/20
# 47/47 [==============================] - 27s 583ms/step - loss: 0.0458 - accuracy: 0.9878 - val_loss: 0.2583 - val_accuracy: 0.9427
# Epoch 15/20
# 47/47 [==============================] - 28s 588ms/step - loss: 0.1105 - accuracy: 0.9801 - val_loss: 0.1033 - val_accuracy: 0.9688
# Epoch 16/20
# 47/47 [==============================] - 27s 578ms/step - loss: 0.0343 - accuracy: 0.9861 - val_loss: 0.1872 - val_accuracy: 0.9427
# Epoch 17/20
# 47/47 [==============================] - 28s 601ms/step - loss: 0.0521 - accuracy: 0.9864 - val_loss: 0.2604 - val_accuracy: 0.9531
# Epoch 18/20
# 47/47 [==============================] - 29s 609ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1457 - val_accuracy: 0.9740
# Epoch 19/20
# 47/47 [==============================] - 27s 578ms/step - loss: 0.0586 - accuracy: 0.9861 - val_loss: 0.5022 - val_accuracy: 0.9219
# Epoch 20/20
# 47/47 [==============================] - 29s 623ms/step - loss: 0.0685 - accuracy: 0.9907 - val_loss: 0.2462 - val_accuracy: 0.9531
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 148, 148, 24)      672
# _________________________________________________________________
# activation_4 (Activation)    (None, 148, 148, 24)      0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 74, 74, 24)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 72, 72, 48)        10416
# _________________________________________________________________
# activation_5 (Activation)    (None, 72, 72, 48)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 36, 36, 48)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 34, 34, 64)        27712
# _________________________________________________________________
# activation_6 (Activation)    (None, 34, 34, 64)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 15, 15, 96)        55392
# _________________________________________________________________
# activation_7 (Activation)    (None, 15, 15, 96)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 7, 7, 96)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4704)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               602240
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 730,227
# Trainable params: 730,227
# Non-trainable params: 0
# _________________________________________________________________
# None
# INFO:tensorflow:Assets written to: Covid_Phenomena_FirstTrail.model\assets

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Accuracy', 'Val_Accuracy'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Loss', 'Val_Loss'], loc='upper left')
plt.show()
